# %%
import os
import requests
import json
import pandas as pd
from dotenv import load_dotenv
from Ticker_Data import og_data
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# [*********************100%***********************]  691 of 691 completed

# %% [markdown]
# # Financial Data

# %%
og_data
# Out:
#             Adj Close                                                \
#                 AAGIY         AAP        AAPL        AAT      AAVMY
# Date
# 2022-08-17  38.170048  202.686813  173.520615  28.259022   9.905236
# 2022-08-18  37.513298  200.283310  173.122971  28.562067   9.775270
# 2022-08-19  37.297649  199.829620  170.508484  28.116968   9.435054
# 2022-08-22  37.268242  191.586243  166.581772  27.359352   9.046918
# 2022-08-23  37.317249  192.136444  166.243759  27.008957   9.171504
# ...               ...         ...         ...        ...        ...
# 2023-08-10  37.799999   71.529999  177.729996  22.190001  15.690000
# 2023-08-11  36.709999   72.279999  177.789993  22.280001  15.440000
# 2023-08-14  36.389999   71.110001  179.460007  21.930000  15.300000
# 2023-08-15  35.610001   69.730003  177.449997  21.260000  15.260000
# 2023-08-16  35.240002   69.870003  176.570007  20.969999  15.170000
#
# ...

# %%
Adj_Close = og_data.loc[:, ("Adj Close")]
Adj_Close = Adj_Close.reset_index()
Adj_Close = Adj_Close.rename(columns={'Date': 'TransactionDate'})
Adj_Close
# Out:
#     TransactionDate      AAGIY         AAP        AAPL        AAT      AAVMY  \
# 0        2022-08-17  38.170048  202.686813  173.520615  28.259022   9.905236
# 1        2022-08-18  37.513298  200.283310  173.122971  28.562067   9.775270
# 2        2022-08-19  37.297649  199.829620  170.508484  28.116968   9.435054
# 3        2022-08-22  37.268242  191.586243  166.581772  27.359352   9.046918
# 4        2022-08-23  37.317249  192.136444  166.243759  27.008957   9.171504
# ..              ...        ...         ...         ...        ...        ...
# 246      2023-08-10  37.799999   71.529999  177.729996  22.190001  15.690000
# 247      2023-08-11  36.709999   72.279999  177.789993  22.280001  15.440000
# 248      2023-08-14  36.389999   71.110001  179.460007  21.930000  15.300000
# 249      2023-08-15  35.610001   69.730003  177.449997  21.260000  15.260000
# 250      2023-08-16  35.240002   69.870003  176.570007  20.969999  15.170000
#
# ...

# %%
Open = og_data.loc[:, ("Open")]
Open = Open.reset_index()
Open = Open.rename(columns={'Date': 'TransactionDate'})
Open
# Out:
#     TransactionDate      AAGIY         AAP        AAPL        AAT   AAVMY  \
# 0        2022-08-17  38.240002  207.940002  172.770004  30.260000  10.610
# 1        2022-08-18  38.599998  209.779999  173.750000  30.010000  10.550
# 2        2022-08-19  38.500000  206.059998  173.029999  30.040001   9.880
# 3        2022-08-22  38.020000  204.990005  169.690002  29.450001   9.580
# 4        2022-08-23  38.000000  199.529999  167.080002  28.860001   9.660
# ..              ...        ...         ...         ...        ...     ...
# 246      2023-08-10  37.750000   71.559998  179.479996  22.410000  15.740
# 247      2023-08-11  36.799999   70.870003  177.320007  22.090000  15.370
# 248      2023-08-14  36.200001   71.599998  177.970001  22.139999  15.469
# 249      2023-08-15  35.500000   70.809998  178.880005  21.610001  15.560
# 250      2023-08-16  35.689999   70.000000  177.130005  21.290001  15.520
#
#          ABBNY        ABBV        ABNB         ABT  ...   YAMHY      YARIY  \
# ...

# %%
High = og_data.loc[:, ("High")]
High = High.reset_index()
High = High.rename(columns={'Date': 'TransactionDate'})
High
# Out:
#     TransactionDate      AAGIY         AAP        AAPL        AAT   AAVMY  \
# 0        2022-08-17  38.990002  211.860001  176.149994  30.290001  10.750
# 1        2022-08-18  38.799999  210.229996  174.899994  30.240000  10.580
# 2        2022-08-19  38.500000  207.179993  173.740005  30.040001   9.880
# 3        2022-08-22  39.000000  204.990005  169.860001  29.450001   9.580
# 4        2022-08-23  39.000000  200.490005  168.710007  28.959999   9.670
# ..              ...        ...         ...         ...        ...     ...
# 246      2023-08-10  38.250000   73.059998  180.750000  22.670000  15.740
# 247      2023-08-11  37.110001   72.550003  178.619995  22.309999  15.440
# 248      2023-08-14  36.459999   72.000000  179.690002  22.180000  15.469
# 249      2023-08-15  36.299999   71.169998  179.479996  21.610001  15.560
# 250      2023-08-16  35.689999   70.680000  178.539993  21.320000  15.520
#
#          ABBNY        ABBV        ABNB         ABT  ...   YAMHY      YARIY  \
# ...

# %%
Low = og_data.loc[:, ("Low")]
Low = Low.reset_index()
Low = Low.rename(columns={'Date': 'TransactionDate'})
Low
# Out:
#     TransactionDate      AAGIY         AAP        AAPL        AAT   AAVMY  \
# 0        2022-08-17  38.230000  206.669998  172.570007  29.740000  10.580
# 1        2022-08-18  38.060001  205.770004  173.119995  29.889999  10.300
# 2        2022-08-19  37.889999  205.139999  171.309998  29.430000   9.800
# 3        2022-08-22  37.830002  198.220001  167.139999  28.760000   9.420
# 4        2022-08-23  37.950001  197.750000  166.649994  28.510000   9.560
# ..              ...        ...         ...         ...        ...     ...
# 246      2023-08-10  37.430000   71.059998  177.600006  22.070000  15.661
# 247      2023-08-11  36.540001   70.629997  176.550003  22.080000  15.260
# 248      2023-08-14  36.090000   69.800003  177.309998  21.830000  15.300
# 249      2023-08-15  35.500000   69.400002  177.050003  21.200001  15.260
# 250      2023-08-16  35.080002   69.830002  176.500000  20.940001  15.170
#
#          ABBNY        ABBV        ABNB         ABT  ...   YAMHY      YARIY  \
# ...

# %%
Close = og_data.loc[:, ("Close")]
Close = Close.reset_index()
Close = Close.rename(columns={'Date': 'TransactionDate'})
Close
# Out:
#     TransactionDate      AAGIY         AAP        AAPL        AAT   AAVMY  \
# 0        2022-08-17  38.939999  209.979996  174.550003  29.840000  10.670
# 1        2022-08-18  38.270000  207.490005  174.149994  30.160000  10.530
# 2        2022-08-19  38.049999  207.020004  171.520004  29.690001   9.845
# 3        2022-08-22  38.020000  198.479996  167.570007  28.889999   9.440
# 4        2022-08-23  38.070000  199.050003  167.229996  28.520000   9.570
# ..              ...        ...         ...         ...        ...     ...
# 246      2023-08-10  37.799999   71.529999  177.970001  22.190001  15.690
# 247      2023-08-11  36.709999   72.279999  177.789993  22.280001  15.440
# 248      2023-08-14  36.389999   71.110001  179.460007  21.930000  15.300
# 249      2023-08-15  35.610001   69.730003  177.449997  21.260000  15.260
# 250      2023-08-16  35.240002   69.870003  176.570007  20.969999  15.170
#
#          ABBNY        ABBV        ABNB         ABT  ...   YAMHY      YARIY  \
# ...

# %%
Volume = og_data.loc[:, ("Volume")]
Volume = Volume.reset_index()
Volume = Volume.rename(columns={'Date': 'TransactionDate'})
Volume
# Out:
#     TransactionDate    AAGIY      AAP      AAPL     AAT  AAVMY    ABBNY  \
# 0        2022-08-17   196600   506600  79542000  190300   7500   985600
# 1        2022-08-18   308900   528000  62290100  174200  23500  1026900
# 2        2022-08-19   363500   585300  70346300  172200  23100   957100
# 3        2022-08-22   741600   792000  69026800  172500  58200  1591100
# 4        2022-08-23   453300  1022800  54147100  165100  35700  1268600
# ..              ...      ...      ...       ...     ...    ...      ...
# 246      2023-08-10  4696000  1750700  54686900  302600   6200   197200
# 247      2023-08-11  2271200  1182900  51988100  145200   4900   106000
# 248      2023-08-14  2614400  3057200  43675600  225500   3800   136900
# 249      2023-08-15  2332500  1282000  43622600  264700  10300   123600
# 250      2023-08-16  2012600  1431800  46876800  325800   5500   468200
#
#         ABBV     ABNB      ABT  ...  YAMHY  YARIY  YASKY      YOU     YUMC  \
# ...

# %% [markdown]
# # Main Congress Dataframe

# %%
#API call to retrieve JSON data of people in congress and transactions

url = "https://api.quiverquant.com/beta/bulk/congresstrading"

headers = {
    "Accept": "application/json",
    "Authorization": "Bearer 77edeff3a3bd2fa2e10472e0536c0d166c147afa"
}

response = requests.get(url, headers=headers).json()

# %%
#For loop to get all congress names and transactions into list

list_series = []

for row in response:
    list_series.append(pd.Series(row))
    column_names = response

# %%
#put list into dataframe
congress_df = pd.DataFrame(data=list_series)

# %%
congress_df
# Out:
#            Representative  ReportDate TransactionDate Ticker Transaction  \
# 0        Tommy Tuberville  2023-08-14      2023-07-27    CCL        Sale
# 1        Tommy Tuberville  2023-08-14      2023-07-25    PFE    Purchase
# 2        Tommy Tuberville  2023-08-14      2023-07-25    KEY    Purchase
# 3        Tommy Tuberville  2023-08-14      2023-07-25   FGBI    Purchase
# 4        Tommy Tuberville  2023-08-14      2023-07-25   FGBI    Purchase
# ...                   ...         ...             ...    ...         ...
# 30743  Sheldon Whitehouse  2016-01-20      2016-01-05   NVDA    Purchase
# 30744        Bill Cassidy  2016-01-12      2016-01-05   AAPL    Purchase
# 30745        Bill Cassidy  2016-01-12      2016-01-05    CMI    Purchase
# 30746        Bill Cassidy  2016-01-12      2016-01-05   INTC        Sale
# 30747         John Hoeven  2016-01-12      2016-01-06     UA    Purchase
#
#                     Range   House   Amount Party
# ...

# %%
#Define list of active senators by seeing who made a transaction within the last 3 months
Active_Senators = congress_df[congress_df["TransactionDate"] > "2023-05-15"]
Active_Senators['Representative'].value_counts()
# Out:
# Daniel Goldman               504
# Zoe Lofgren                   72
# Tommy Tuberville              70
# Josh Gottheimer               62
# Lois Frankel                  37
# Kevin Hern                    18
# Mark Dr Green                 15
# Thomas R. Carper              13
# Jonathan Jackson              12
# Michael C. Burgess            12
# John Curtis                   11
# Virginia Foxx                  8
# Shelley Moore Capito           8
# Pete Sessions                  8
# Rick Larsen                    8
# William R. Keating             6
# Lloyd Doggett                  6
# Earl Blumenauer                4
# Dwight Evans                   4
# Michael Garcia                 3
# Steve Cohen                    2
# Mary Gay Scanlon               2
# Maria Elvira Salazar           2
# John Hickenlooper              2
# Nancy Pelosi                   2
# Robert E. Latta                2
# Daniel Meuser                  1
# James E Hon Banks              1
# ...

# %%
len(congress_df.index)
# Out:
# 30748

# %%
#Count transactions per senator
congress_df['Representative'].value_counts().head(10)
# Out:
# David Perdue         2541
# Josh Gottheimer      1984
# Gilbert Cisneros     1218
# Susie Lee            1191
# Daniel Goldman       1134
# Greg Gianforte       1118
# Dean Phillips         963
# Alan S. Lowenthal     941
# Lois Frankel          776
# Tommy Tuberville      764
# Name: Representative, dtype: int64

# %%
#Count most traded tickers
congress_df['Ticker'].value_counts().head(10)
# Out:
# AAPL    523
# MSFT    406
# AMZN    244
# DIS     219
# NVDA    217
# T       194
# PFE     186
# PYPL    171
# FB      168
# XOM     163
# Name: Ticker, dtype: int64

# %% [markdown]
# # Representative DataFrames

# %% [markdown]
# ## Daniel Goldman

# %%
#Create dataframe for Senator Daniel Goldman
Daniel_Goldman = congress_df[congress_df["Representative"] == "Daniel Goldman"]
Daniel_Goldman
# Out:
#       Representative  ReportDate TransactionDate Ticker Transaction  \
# 18    Daniel Goldman  2023-08-13      2023-07-19    NOC        Sale
# 19    Daniel Goldman  2023-08-13      2023-07-14   TMUS        Sale
# 20    Daniel Goldman  2023-08-13      2023-07-14    THO        Sale
# 21    Daniel Goldman  2023-08-13      2023-07-14   ABBV        Sale
# 22    Daniel Goldman  2023-08-13      2023-07-14      F        Sale
# ...              ...         ...             ...    ...         ...
# 2549  Daniel Goldman  2023-02-24      2023-01-13  KDDIY    Purchase
# 2550  Daniel Goldman  2023-02-24      2023-01-13  STBFY    Purchase
# 2551  Daniel Goldman  2023-02-24      2023-01-13  TOSYY    Purchase
# 2552  Daniel Goldman  2023-02-24      2023-01-13  TRYIY    Purchase
# 2553  Daniel Goldman  2023-02-24      2023-01-13  ZURVY        Sale
#
#                 Range            House   Amount Party
# 18    $15,001-$50,000  Representatives  15001.0     D
# ...

# %%
Daniel_Goldman.count()
# Out:
# Representative     1134
# ReportDate         1134
# TransactionDate    1134
# Ticker             1134
# Transaction        1134
# Range              1134
# House              1134
# Amount             1134
# Party              1134
# dtype: int64

# %%
#List tickers and number of transactions of that stock
Daniel_Goldman["Ticker"].value_counts()
# Out:
# KO       7
# TSLA     6
# MRK      5
# ZTS      5
# MO       5
#         ..
# CRH      1
# TAK      1
# CRARY    1
# CODYY    1
# PSO      1
# Name: Ticker, Length: 698, dtype: int64

# %%
#List all traded stocks by DG
DG_unique = Daniel_Goldman["Ticker"].unique()
display(DG_unique)
len(DG_unique)
# Out:
# array(['NOC', 'TMUS', 'THO', 'ABBV', 'F', 'T', 'MRK', 'COIN', 'MO', 'JNJ',
#        'KO', 'DAR', 'TEL', 'PLD', 'ZTS', 'TSN', 'VTR', 'APTV', 'LHX',
#        'PODD', 'PYPL', 'VZ', 'IIPR', 'PK', 'AVB', 'AAP', 'PEAK', 'LBTYA',
#        'SR', 'LBTYK', 'ADC', 'LSI', 'PARAA', 'HALO', 'IRM', 'GILD', 'PD',
#        'GTY', 'JAZZ', 'TEAM', 'ANET', 'WELL', 'LMT', 'WPM', 'HEI.A',
#        'ALEX', 'ARE', 'SGH', 'SLG', 'LVMUY', 'MTB', 'MKTX', 'SBGI',
#        'MELI', 'AYX', 'ADM', 'OGS', 'AMCX', 'AMCR', 'AMT', 'MAA', 'STT',
#        'FCPT', 'FNF', 'STX', 'FIS', 'SBAC', 'BFS', 'JBGS', 'IRT', 'FERG',
#        'IOT', 'KDP', 'KRC', 'FN', 'RTX', 'EXR', 'ICHR', 'RLJ', 'EXC',
#        'ES', 'ROIC', 'KRG', 'KR', 'RLAY', 'RWT', 'EVBG', 'ESS', 'EPRT',
#        'EQR', 'EQIX', 'EPR', 'EPAM', 'ENTA', 'EIX', 'D', 'DLTR', 'DG',
#        'URI', 'UPS', 'SKT', 'UDR', 'USB', 'TFC', 'RBA', 'IFF', 'TRIP',
#        'QDEL', 'YUMC', 'TMO', 'MRNA', 'MOH', 'MOS', 'KHC', 'NSA', 'KLIC',
# ...

# %%
#Remove and rename stock tickers so Yahoo Finance can download data 
Daniel_Goldman_Clean = Daniel_Goldman[(Daniel_Goldman.Ticker != "RTN") & 
                                     (Daniel_Goldman.Ticker != "ESALY") &
                                     (Daniel_Goldman.Ticker != "RDSMY") &
                                     (Daniel_Goldman.Ticker != "MAXR") &
                                     (Daniel_Goldman.Ticker != "FRC") &
                                     (Daniel_Goldman.Ticker != "CS")]

Daniel_Goldman_Clean["Ticker"] = Daniel_Goldman_Clean["Ticker"].str.replace("BRK.B", "BRK-B")
Daniel_Goldman_Clean["Ticker"] = Daniel_Goldman_Clean["Ticker"].str.replace("HEI.A", "HEI-A")
Daniel_Goldman_Clean.dtypes
# Out:
# Representative      object
# ReportDate          object
# TransactionDate     object
# Ticker              object
# Transaction         object
# Range               object
# House               object
# Amount             float64
# Party               object
# dtype: object

# %%
#Update data types so that they can be merged with financial data
Daniel_Goldman_Clean["TransactionDate"] = pd.to_datetime(Daniel_Goldman_Clean["TransactionDate"], format="%Y-%m-%d")
Daniel_Goldman_Clean["ReportDate"] = pd.to_datetime(Daniel_Goldman_Clean["ReportDate"], format="%Y-%m-%d")
Daniel_Goldman_Clean.dtypes
# Out:
# Representative             object
# ReportDate         datetime64[ns]
# TransactionDate    datetime64[ns]
# Ticker                     object
# Transaction                object
# Range                      object
# House                      object
# Amount                    float64
# Party                      object
# dtype: object

# %%
# Merge Volume Data
df_volume = Volume.melt(id_vars='TransactionDate', var_name='Ticker', value_name='Volume')
#df.dtypes
#Daniel_Goldman_Clean.dtypes
DG1 = Daniel_Goldman_Clean.merge(df_volume, on = ["TransactionDate",'Ticker'])
DG1
# Out:
#       Representative ReportDate TransactionDate Ticker Transaction  \
# 0     Daniel Goldman 2023-08-13      2023-07-19    NOC        Sale
# 1     Daniel Goldman 2023-08-13      2023-07-14   TMUS        Sale
# 2     Daniel Goldman 2023-08-13      2023-07-14    THO        Sale
# 3     Daniel Goldman 2023-08-13      2023-07-14   ABBV        Sale
# 4     Daniel Goldman 2023-08-13      2023-07-14      F        Sale
# ...              ...        ...             ...    ...         ...
# 1121  Daniel Goldman 2023-02-24      2023-01-13  KDDIY    Purchase
# 1122  Daniel Goldman 2023-02-24      2023-01-13  STBFY    Purchase
# 1123  Daniel Goldman 2023-02-24      2023-01-13  TOSYY    Purchase
# 1124  Daniel Goldman 2023-02-24      2023-01-13  TRYIY    Purchase
# 1125  Daniel Goldman 2023-02-24      2023-01-13  ZURVY        Sale
#
#                 Range            House   Amount Party      Volume
# 0     $15,001-$50,000  Representatives  15001.0     D    933600.0
# ...

# %%
#Check that data is correct
Volume[Volume["TransactionDate"] == "2023-07-14" ]
# Out:
#     TransactionDate   AAGIY      AAP      AAPL     AAT  AAVMY   ABBNY  \
# 227      2023-07-14  423200  2386200  41573900  222400   5800  142100
#
#         ABBV     ABNB      ABT  ...  YAMHY  YARIY  YASKY      YOU     YUMC  \
# 227  5543400  6496600  4015600  ...    700  10300   4600  1070300  1251200
#
#            Z  ZLNDY       ZS      ZTS  ZURVY
# 227  2313300   8800  2495900  2455900  53800
#
# [1 rows x 692 columns]

# %%
# Merge Close Data
df_close = Close.melt(id_vars='TransactionDate', var_name='Ticker', value_name='Close')
#df.dtypes
#Daniel_Goldman_Clean.dtypes
DG2 = DG1.merge(df_close, on = ["TransactionDate",'Ticker'])
DG2
# Out:
#       Representative ReportDate TransactionDate Ticker Transaction  \
# 0     Daniel Goldman 2023-08-13      2023-07-19    NOC        Sale
# 1     Daniel Goldman 2023-08-13      2023-07-14   TMUS        Sale
# 2     Daniel Goldman 2023-08-13      2023-07-14    THO        Sale
# 3     Daniel Goldman 2023-08-13      2023-07-14   ABBV        Sale
# 4     Daniel Goldman 2023-08-13      2023-07-14      F        Sale
# ...              ...        ...             ...    ...         ...
# 1121  Daniel Goldman 2023-02-24      2023-01-13  KDDIY    Purchase
# 1122  Daniel Goldman 2023-02-24      2023-01-13  STBFY    Purchase
# 1123  Daniel Goldman 2023-02-24      2023-01-13  TOSYY    Purchase
# 1124  Daniel Goldman 2023-02-24      2023-01-13  TRYIY    Purchase
# 1125  Daniel Goldman 2023-02-24      2023-01-13  ZURVY        Sale
#
#                 Range            House   Amount Party      Volume       Close
# 0     $15,001-$50,000  Representatives  15001.0     D    933600.0  442.279999
# ...

# %%
#Check that data is correct
Close[Close["TransactionDate"] == "2023-07-14" ]
# Out:
#     TransactionDate      AAGIY        AAP        AAPL        AAT  AAVMY  \
# 227      2023-07-14  40.889999  70.639999  190.690002  20.790001  16.82
#
#      ABBNY        ABBV        ABNB     ABT  ...  YAMHY      YARIY      YASKY  \
# 227  39.43  136.009995  143.339996  107.93  ...  14.01  19.309999  87.349998
#
#        YOU       YUMC      Z  ZLNDY          ZS         ZTS      ZURVY
# 227  25.01  60.009998  53.23  15.73  145.429993  172.190002  47.459999
#
# [1 rows x 692 columns]

# %% [markdown]
# ## David Perdue

# %%
David_Perdue = congress_df[congress_df["Representative"] == "David Perdue"]
David_Perdue

# %%
David_Perdue.count()

# %%
David_Perdue["Ticker"].value_counts().head(10)

# %%
DP_unique = David_Perdue["Ticker"].unique()
display(DP_unique)
len(DP_unique)

# %%
David_Perdue_PFE = David_Perdue[David_Perdue["Ticker"] == "PFE"]
David_Perdue_PFE

# %%
David_Perdue_AAPL_Purchase = David_Perdue_AAPL[David_Perdue_AAPL["Transaction"] == "Purchase"]
David_Perdue_AAPL_Purchase.head()

# %%
David_Perdue_AAPL_Sell = David_Perdue_AAPL[David_Perdue_AAPL["Transaction"] == "Sale"]
David_Perdue_AAPL_Sell.head()

# %% [markdown]
# # Ticker DataFrames

# %%
AAPL = congress_df[congress_df["Ticker"] == "AAPL"]
AAPL
